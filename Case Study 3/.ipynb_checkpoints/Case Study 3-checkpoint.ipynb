# %%
#import all packages needed
import pandas as pd
import pyreadr
from pandas_profiling import ProfileReport

# %% [markdown]
# https://github.com/jjschueder/7333QTW/blob/master/Case%20Study%203/Py%20read%20R.JPG

# %%
#import the dataset
result = pyreadr.read_r(r'C:\Users\jjsch\Downloads\Week_5_Materials_2\data.rda')

# %%
#convert to a dataframe
df = result["emailDFrp"]

# %%
#view data sample
df
# Out:
#      isSpam isRe underscore priority isInReplyTo sortedRec subPunc  \
# 0         0    T          F        F           T         T       F
# 1         0    F          F        F           F         T       F
# 2         0    F          F        F           F         T       F
# 3         0    F          F        F           F         T       F
# 4         0    T          F        F           F         T       F
# ...     ...  ...        ...      ...         ...       ...     ...
# 9343      1    F          F        F           F         T       F
# 9344      1    F          F        F           F         T       F
# 9345      1    F          F        F           F         F       F
# 9346      1    F          F        F           F         T       F
# 9347      1    F          F        F           F         T       F
#
#      multipartText hasImages isPGPsigned  ... subQuesCt numAtt numRec  \
# 0                F         F           F  ...         0    0.0      2
# 1                F         F           F  ...         0    0.0      1
# 2                F         F           F  ...         0    0.0      1
# 3                F         F           F  ...         0    0.0      0
# 4                F         F           F  ...         0    0.0      1
# ...            ...       ...         ...  ...       ...    ...    ...
# 9343             F         F           F  ...         1    0.0      1
# 9344             T         F           F  ...         0    1.0      1
# 9345             F         F           F  ...         0    0.0      1
# 9346             F         F           F  ...         0    0.0      1
# 9347             F         F           F  ...         0    0.0      1
#
#        perCaps  hour    perHTML  subBlanks  forwards  avgWordLen numDlr
# 0     4.451039  11.0   0.000000  12.500000  0.000000    4.376623      3
# 1     7.491289  11.0   0.000000   8.000000  0.000000    4.555556      0
# 2     7.436096  12.0   0.000000   8.000000  0.000000    4.817164      0
# 3     5.090909  13.0   0.000000  18.918919  3.125000    4.714286      0
# 4     6.116643  13.0   0.000000  15.217391  6.451613    4.234940      0
# ...        ...   ...        ...        ...       ...         ...    ...
# 9343  8.572552  21.0  79.657111  13.793103  0.000000    4.700555      2
# 9344  9.436009  23.0   0.000000  10.526316  0.000000    4.904255      4
# 9345  2.418448   8.0   0.000000  20.000000  0.000000    4.703704      0
# 9346  7.795400  23.0   0.000000   5.263158  0.000000    5.252690     80
# 9347  4.783951   6.0   0.000000  14.285714  0.000000    4.823821      1
#
# [9348 rows x 30 columns]

# %%
df['isSpam'] = df['isSpam'].map({'T': 1, 'F': 0})
isRe             
underscore       
priority         
isInReplyTo      
sortedRec        
subPunc          
multipartText    
hasImages        
isPGPsigned      
subSpamWords     
noHost           
numEnd           
isYelling        
isOrigMsg        
isDear           
isWrote

# %%
df.describe()
# Out:
#           numLines     bodyCharCt       numAtt      perCaps         hour  \
# count  9348.000000    9348.000000  9348.000000  9348.000000  9348.000000
# mean     66.908537    2844.091463     0.065789     8.850371    12.210847
# std     147.955886    6711.335668     0.324879     9.583415     6.623932
# min       2.000000       6.000000     0.000000     0.000000     0.000000
# 25%      19.000000     587.000000     0.000000     4.255319     8.000000
# 50%      32.000000    1088.500000     0.000000     6.055473    13.000000
# 75%      59.000000    2192.000000     0.000000     9.059399    18.000000
# max    6319.000000  188505.000000    18.000000   100.000000    23.000000
#
#            perHTML    subBlanks     forwards   avgWordLen       numDlr
# count  9348.000000  9328.000000  9348.000000  9348.000000  9348.000000
# mean      6.517082    13.866939    10.445086     4.487222     1.781558
# std      19.135266     7.431938    18.263576     0.568582    30.380455
# min       0.000000     0.000000     0.000000     1.363072     0.000000
# 25%       0.000000    10.526316     0.000000     4.208257     0.000000
# 50%       0.000000    13.253012     0.000000     4.454545     0.000000
# 75%       0.000000    15.686275    15.384615     4.728507     0.000000
# max     100.000000    86.419753    99.058270    26.000000  1977.000000

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['isSpam', 'isRe', 'underscore', 'priority', 'isInReplyTo', 'sortedRec',
#        'subPunc', 'multipartText', 'hasImages', 'isPGPsigned', 'subSpamWords',
#        'noHost', 'numEnd', 'isYelling', 'isOrigMsg', 'isDear', 'isWrote',
#        'numLines', 'bodyCharCt', 'subExcCt', 'subQuesCt', 'numAtt', 'numRec',
#        'perCaps', 'hour', 'perHTML', 'subBlanks', 'forwards', 'avgWordLen',
#        'numDlr'],
#       dtype='object')

# %%
df.dtypes
# Out:
# isSpam           category
# isRe             category
# underscore       category
# priority         category
# isInReplyTo      category
# sortedRec        category
# subPunc          category
# multipartText    category
# hasImages        category
# isPGPsigned      category
# subSpamWords     category
# noHost           category
# numEnd           category
# isYelling        category
# isOrigMsg        category
# isDear           category
# isWrote          category
# numLines            int32
# bodyCharCt          int32
# subExcCt           object
# subQuesCt          object
# numAtt            float64
# numRec             object
# perCaps           float64
# hour              float64
# perHTML           float64
# subBlanks         float64
# forwards          float64
# avgWordLen        float64
# numDlr              int32
# dtype: object

# %%
profile = ProfileReport(df, title='Pandas Profiling Report', explorative=True)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-12-05fe04409c1f> in <module>
# ----> 1 profile = ProfileReport(df, title='Pandas Profiling Report', explorative=True)
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas_profiling\profile_report.py in __init__(self, df, minimal, explorative, config_file, lazy, **kwargs)
#      79         if df is not None:
#      80             # preprocess df
# ---> 81             self.df = self.preprocess(df)
#      82
#      83         if not lazy:
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas_profiling\profile_report.py in preprocess(df)
#     443
#     444         # Rename reserved column names
# --> 445         df = rename_index(df)
#     446
#     447         # Ensure that columns are strings
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas_profiling\utils\dataframe.py in rename_index(df)
#      78         The DataFrame with {index,column} `index` replaced by `df_index`, unchanged if the DataFrame does not contain such a string.
#      79     """
# ---> 80     df.rename(columns={"index": "df_index"}, inplace=True)
#      81
#      82     if "index" in df.index.names:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     219         @wraps(func)
#     220         def wrapper(*args, **kwargs):
# --> 221             return func(*args, **kwargs)
#     222
#     223         kind = inspect.Parameter.POSITIONAL_OR_KEYWORD
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in rename(self, *args, **kwargs)
#    4236         kwargs.pop("axis", None)
#    4237         kwargs.pop("mapper", None)
# -> 4238         return super().rename(**kwargs)
#    4239
#    4240     @Substitution(**_shared_doc_kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in rename(self, *args, **kwargs)
#    1167
#    1168             result._data = result._data.rename_axis(
# -> 1169                 f, axis=baxis, copy=copy, level=level
#    1170             )
#    1171             result._clear_item_cache()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in rename_axis(self, mapper, axis, copy, level)
#     197         level : int, default None
#     198         """
# --> 199         obj = self.copy(deep=copy)
#     200         obj.set_axis(axis, _transform_index(self.axes[axis], mapper, level))
#     201         return obj
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in copy(self, deep)
#     786         else:
#     787             new_axes = list(self.axes)
# --> 788         return self.apply("copy", axes=new_axes, deep=deep, do_integrity_check=False)
#     789
#     790     def as_array(self, transpose=False, items=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#     442             return self.make_empty(axes or self.axes)
#     443         bm = self.__class__(
# --> 444             result_blocks, axes or self.axes, do_integrity_check=do_integrity_check
#     445         )
#     446         bm._consolidate_inplace()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in __init__(self, blocks, axes, do_integrity_check)
#     145         self._consolidate_check()
#     146
# --> 147         self._rebuild_blknos_and_blklocs()
#     148
#     149     def make_empty(self, axes=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in _rebuild_blknos_and_blklocs(self)
#     229
#     230         if (new_blknos == -1).any():
# --> 231             raise AssertionError("Gaps in blk ref_locs")
#     232
#     233         self._blknos = new_blknos
#
# AssertionError: Gaps in blk ref_locs

# %%
profile
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Summarize dataset', max=44.0, style=ProgressStyle(descrip…
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas_profiling\profile_report.py in _repr_html_(self)
#     395     def _repr_html_(self):
#     396         """The ipython notebook widgets user interface gets called by the jupyter notebook."""
# --> 397         self.to_notebook_iframe()
#     398
#     399     def __repr__(self):
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas_profiling\profile_report.py in to_notebook_iframe(self)
#     375         with warnings.catch_warnings():
#     376             warnings.simplefilter("ignore")
# --> 377             display(get_notebook_iframe(self))
#     378
#     379     def to_widgets(self):
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas_profiling\report\presentation\flavours\widget\notebook.py in get_notebook_iframe(profile)
#      63         output = get_notebook_iframe_src(profile)
#      64     elif attribute == "srcdoc":
# ---> 65         output = get_notebook_iframe_srcdoc(profile)
#      66     else:
#      67         raise ValueError(
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas_profiling\report\presentation\flavours\widget\notebook.py in get_notebook_iframe_srcdoc(profile)
#      21     width = config["notebook"]["iframe"]["width"].get(str)
#      22     height = config["notebook"]["iframe"]["height"].get(str)
# ---> 23     src = html.escape(profile.to_html())
#      24
#      25     iframe = f'<iframe width="{width}" height="{height}" srcdoc="{src}" frameborder="0" allowfullscreen></iframe>'
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas_profiling\profile_report.py in to_html(self)
#     346
#     347         """
# --> 348         return self.html
#     349
#     350     def to_json(self) -> str:
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas_profiling\profile_report.py in html(self)
#     166     def html(self):
#     167         if self._html is None:
# --> 168             self._html = self._render_html()
#     169         return self._html
#     170
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas_profiling\profile_report.py in _render_html(self)
#     273         from pandas_profiling.report.presentation.flavours import HTMLReport
#     274
# --> 275         report = self.report
#     276
#     277         disable_progress_bar = not config["progress_bar"].get(bool)
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas_profiling\profile_report.py in report(self)
#     160     def report(self):
#     161         if self._report is None:
# --> 162             self._report = get_report_structure(self.description_set)
#     163         return self._report
#     164
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas_profiling\profile_report.py in description_set(self)
#     141     def description_set(self):
#     142         if self._description_set is None:
# --> 143             self._description_set = describe_df(self.title, self.df)
#     144         return self._description_set
#     145
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas_profiling\model\describe.py in describe(title, df)
#     101         # missing diagrams
#     102         pbar.set_postfix_str("Get missing diagrams")
# --> 103         missing = get_missing_diagrams(df, table_stats)
#     104         pbar.update()
#     105
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas_profiling\model\summary.py in get_missing_diagrams(df, table_stats)
#     645                     missing[name] = {
#     646                         "name": settings["name"],
# --> 647                         "matrix": missing_diagram(name)(df),
#     648                     }
#     649             except ValueError as e:
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas_profiling\visualisation\missing.py in missing_bar(data)
#      69         color=hex_to_rgb(config["html"]["style"]["primary_color"].get(str)),
#      70         fontsize=get_font_size(data),
# ---> 71         labels=labels,
#      72     )
#      73     for ax0 in plt.gcf().get_axes():
#
# ~\AppData\Roaming\Python\Python37\site-packages\missingno\missingno.py in bar(df, figsize, fontsize, labels, log, color, inline, filter, n, p, sort, ax)
#     224     df = nullity_filter(df, filter=filter, n=n, p=p)
#     225     df = nullity_sort(df, sort=sort, axis='rows')
# --> 226     nullity_counts = len(df) - df.isnull().sum()
#     227
#     228     if ax is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in isnull(self)
#    4722     @Appender(_shared_docs["isna"] % _shared_doc_kwargs)
#    4723     def isnull(self):
# -> 4724         return super().isnull()
#    4725
#    4726     @Appender(_shared_docs["notna"] % _shared_doc_kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in isnull(self)
#    7320     @Appender(_shared_docs["isna"] % _shared_doc_kwargs)
#    7321     def isnull(self):
# -> 7322         return isna(self).__finalize__(self)
#    7323
#    7324     _shared_docs[
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\dtypes\missing.py in isna(obj)
#     120     Name: 1, dtype: bool
#     121     """
# --> 122     return _isna(obj)
#     123
#     124
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\dtypes\missing.py in _isna_new(obj)
#     147         return _isna_ndarraylike(obj)
#     148     elif isinstance(obj, ABCGeneric):
# --> 149         return obj._constructor(obj._data.isna(func=isna))
#     150     elif isinstance(obj, list):
#     151         return _isna_ndarraylike(np.asarray(obj, dtype=object))
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in isna(self, func, **kwargs)
#     552
#     553     def isna(self, func, **kwargs):
# --> 554         return self.apply("apply", func=func, **kwargs)
#     555
#     556     def where(self, **kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#     442             return self.make_empty(axes or self.axes)
#     443         bm = self.__class__(
# --> 444             result_blocks, axes or self.axes, do_integrity_check=do_integrity_check
#     445         )
#     446         bm._consolidate_inplace()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in __init__(self, blocks, axes, do_integrity_check)
#     145         self._consolidate_check()
#     146
# --> 147         self._rebuild_blknos_and_blklocs()
#     148
#     149     def make_empty(self, axes=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in _rebuild_blknos_and_blklocs(self)
#     229
#     230         if (new_blknos == -1).any():
# --> 231             raise AssertionError("Gaps in blk ref_locs")
#     232
#     233         self._blknos = new_blknos
#
# AssertionError: Gaps in blk ref_locs
