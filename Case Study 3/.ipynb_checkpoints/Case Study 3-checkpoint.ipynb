# %%
#import all packages needed
import pandas as pd
import pyreadr
from pandas_profiling import ProfileReport

# %% [markdown]
# https://github.com/jjschueder/7333QTW/blob/master/Case%20Study%203/Py%20read%20R.JPG

# %%
#import the dataset
#result = pyreadr.read_r(r'C:\Users\jjsch\Downloads\Week_5_Materials_2\data.Rda')

# %%
#df.to_csv(r'C:\Users\jjsch\Downloads\Week_5_Materials_2\data.csv')

# %%
#convert to a dataframe
#df = result["emailDFrp"]

# %%
#view data sample
df = pd.read_csv(r'https://raw.githubusercontent.com/jjschueder/7333QTW/master/Case%20Study%203/data.csv')
df
# Out:
#       Unnamed: 0  isSpam isRe underscore priority isInReplyTo sortedRec  \
# 0              0       0    T          F        F           T         T
# 1              1       0    F          F        F           F         T
# 2              2       0    F          F        F           F         T
# 3              3       0    F          F        F           F         T
# 4              4       0    T          F        F           F         T
# ...          ...     ...  ...        ...      ...         ...       ...
# 9343        9343       1    F          F        F           F         T
# 9344        9344       1    F          F        F           F         T
# 9345        9345       1    F          F        F           F         F
# 9346        9346       1    F          F        F           F         T
# 9347        9347       1    F          F        F           F         T
#
#      subPunc multipartText hasImages  ... subQuesCt numAtt numRec   perCaps  \
# 0          F             F         F  ...       0.0    0.0    2.0  4.451039
# 1          F             F         F  ...       0.0    0.0    1.0  7.491289
# 2          F             F         F  ...       0.0    0.0    1.0  7.436096
# 3          F             F         F  ...       0.0    0.0    0.0  5.090909
# 4          F             F         F  ...       0.0    0.0    1.0  6.116643
# ...      ...           ...       ...  ...       ...    ...    ...       ...
# 9343       F             F         F  ...       1.0    0.0    1.0  8.572552
# 9344       F             T         F  ...       0.0    1.0    1.0  9.436009
# 9345       F             F         F  ...       0.0    0.0    1.0  2.418448
# 9346       F             F         F  ...       0.0    0.0    1.0  7.795400
# 9347       F             F         F  ...       0.0    0.0    1.0  4.783951
#
#       hour    perHTML  subBlanks  forwards  avgWordLen  numDlr
# 0     11.0   0.000000  12.500000  0.000000    4.376623       3
# 1     11.0   0.000000   8.000000  0.000000    4.555556       0
# 2     12.0   0.000000   8.000000  0.000000    4.817164       0
# 3     13.0   0.000000  18.918919  3.125000    4.714286       0
# 4     13.0   0.000000  15.217391  6.451613    4.234940       0
# ...    ...        ...        ...       ...         ...     ...
# 9343  21.0  79.657111  13.793103  0.000000    4.700555       2
# 9344  23.0   0.000000  10.526316  0.000000    4.904255       4
# 9345   8.0   0.000000  20.000000  0.000000    4.703704       0
# 9346  23.0   0.000000   5.263158  0.000000    5.252690      80
# 9347   6.0   0.000000  14.285714  0.000000    4.823821       1
#
# [9348 rows x 31 columns]

# %%
#df['isSpam'] = df['isSpam'].map({'T': 1, 'F': 0})
df['isRe'] = df['isRe'].map({'T': 1, 'F': 0})             
df['underscore'] = df['underscore'].map({'T': 1, 'F': 0})       
df['priority'] = df['priority'].map({'T': 1, 'F': 0})         
df['isInReplyTo'] = df['isInReplyTo'].map({'T': 1, 'F': 0})      
df['sortedRec'] = df['sortedRec'].map({'T': 1, 'F': 0})        
df['subPunc'] = df['subPunc'].map({'T': 1, 'F': 0})          
df['multipartText'] = df['multipartText'].map({'T': 1, 'F': 0})    
df['hasImages'] = df['hasImages'].map({'T': 1, 'F': 0})        
df['isPGPsigned'] = df['isPGPsigned'].map({'T': 1, 'F': 0})       
df['subSpamWords'] = df['subSpamWords'].map({'T': 1, 'F': 0})      
df['noHost'] = df['noHost'].map({'T': 1, 'F': 0})            
df['numEnd'] = df['numEnd'].map({'T': 1, 'F': 0})            
df['isYelling'] = df['isYelling'].map({'T': 1, 'F': 0})         
df['isOrigMsg'] = df['isOrigMsg'].map({'T': 1, 'F': 0})         
df['isDear'] = df['isDear'].map({'T': 1, 'F': 0})            
df['isWrote'] = df['isWrote'].map({'T': 1, 'F': 0})

# %%
df.describe()
# Out:
#         Unnamed: 0       isSpam         isRe   underscore     priority  \
# count  9348.000000  9348.000000  9348.000000  9348.000000  9348.000000
# mean   4673.500000     0.256418     0.321459     0.013479     0.005777
# std    2698.679492     0.436679     0.467062     0.115319     0.075788
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%    2336.750000     0.000000     0.000000     0.000000     0.000000
# 50%    4673.500000     0.000000     0.000000     0.000000     0.000000
# 75%    7010.250000     1.000000     1.000000     0.000000     0.000000
# max    9347.000000     1.000000     1.000000     1.000000     1.000000
#
#        isInReplyTo    sortedRec      subPunc  multipartText    hasImages  ...  \
# count  9348.000000  9348.000000  9348.000000    9348.000000  9348.000000  ...
# mean      0.298674     0.898588     0.028134       0.035088     0.002353  ...
# std       0.457701     0.301890     0.165365       0.184011     0.048458  ...
# min       0.000000     0.000000     0.000000       0.000000     0.000000  ...
# 25%       0.000000     1.000000     0.000000       0.000000     0.000000  ...
# 50%       0.000000     1.000000     0.000000       0.000000     0.000000  ...
# 75%       1.000000     1.000000     0.000000       0.000000     0.000000  ...
# max       1.000000     1.000000     1.000000       1.000000     1.000000  ...
#
#          subQuesCt       numAtt       numRec      perCaps         hour  \
# count  9328.000000  9348.000000  9066.000000  9348.000000  9348.000000
# mean      0.137757     0.065789     1.929407     8.850371    12.210847
# std       0.507685     0.324879     5.242396     9.583415     6.623932
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     1.000000     4.255319     8.000000
# 50%       0.000000     0.000000     1.000000     6.055473    13.000000
# 75%       0.000000     0.000000     1.000000     9.059399    18.000000
# max      12.000000    18.000000   311.000000   100.000000    23.000000
#
#            perHTML    subBlanks     forwards   avgWordLen       numDlr
# count  9348.000000  9328.000000  9348.000000  9348.000000  9348.000000
# mean      6.517082    13.866939    10.445086     4.487222     1.781558
# std      19.135266     7.431938    18.263576     0.568582    30.380455
# min       0.000000     0.000000     0.000000     1.363072     0.000000
# 25%       0.000000    10.526316     0.000000     4.208257     0.000000
# 50%       0.000000    13.253012     0.000000     4.454545     0.000000
# 75%       0.000000    15.686275    15.384615     4.728507     0.000000
# max     100.000000    86.419753    99.058270    26.000000  1977.000000
#
# [8 rows x 31 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'isSpam', 'isRe', 'underscore', 'priority', 'isInReplyTo',
#        'sortedRec', 'subPunc', 'multipartText', 'hasImages', 'isPGPsigned',
#        'subSpamWords', 'noHost', 'numEnd', 'isYelling', 'isOrigMsg', 'isDear',
#        'isWrote', 'numLines', 'bodyCharCt', 'subExcCt', 'subQuesCt', 'numAtt',
#        'numRec', 'perCaps', 'hour', 'perHTML', 'subBlanks', 'forwards',
#        'avgWordLen', 'numDlr'],
#       dtype='object')

# %%
countOfNan = pd.Series(df.isnull().sum()) 
DataType = pd.Series(df.dtypes) 
  
frame = { 'datatype': DataType, 'count of Nan': countOfNan } 
result = pd.DataFrame(frame) 
result
# Out:
#               datatype  count of Nan
# Unnamed: 0       int64             0
# isSpam           int64             0
# isRe             int64             0
# underscore       int64             0
# priority         int64             0
# isInReplyTo      int64             0
# sortedRec        int64             0
# subPunc          int64             0
# multipartText    int64             0
# hasImages        int64             0
# isPGPsigned      int64             0
# subSpamWords   float64             7
# noHost         float64             1
# numEnd           int64             0
# isYelling      float64             7
# isOrigMsg        int64             0
# isDear           int64             0
# isWrote          int64             0
# numLines         int64             0
# bodyCharCt       int64             0
# subExcCt       float64            20
# subQuesCt      float64            20
# numAtt         float64             0
# numRec         float64           282
# perCaps        float64             0
# hour           float64             0
# perHTML        float64             0
# subBlanks      float64            20
# forwards       float64             0
# avgWordLen     float64             0
# numDlr           int64             0

# %%
#take out Nan
dfNoNa=df[~df['numRec'].isnull()]
dfNoNa=dfNoNa[~dfNoNa['subQuesCt'].isnull()]
dfNoNa=dfNoNa[~dfNoNa['noHost'].isnull()]
# Out:
#               datatype  count of Nan
# Unnamed: 0       int64             0
# isSpam           int64             0
# isRe             int64             0
# underscore       int64             0
# priority         int64             0
# isInReplyTo      int64             0
# sortedRec        int64             0
# subPunc          int64             0
# multipartText    int64             0
# hasImages        int64             0
# isPGPsigned      int64             0
# subSpamWords   float64             7
# noHost         float64             1
# numEnd           int64             0
# isYelling      float64             7
# isOrigMsg        int64             0
# isDear           int64             0
# isWrote          int64             0
# numLines         int64             0
# bodyCharCt       int64             0
# subExcCt       float64            20
# subQuesCt      float64            20
# numAtt         float64             0
# numRec         float64           282
# perCaps        float64             0
# hour           float64             0
# perHTML        float64             0
# subBlanks      float64            20
# forwards       float64             0
# avgWordLen     float64             0
# numDlr           int64             0

# %%
profile = ProfileReport(df, title='Pandas Profiling Report', explorative=True)
# Out:
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "C:\Users\shayden\Anaconda3\envs\RPy\lib\multiprocessing\pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "C:\Users\shayden\Anaconda3\envs\RPy\lib\multiprocessing\pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "C:\Users\shayden\Anaconda3\envs\RPy\lib\site-packages\pandas_profiling\describe.py", line 282, in multiprocess_func
#     return x[0], describe_1d(x[1], **kwargs)
#   File "C:\Users\shayden\Anaconda3\envs\RPy\lib\site-packages\pandas_profiling\describe.py", line 268, in describe_1d
#     result = result.append(describe_boolean_1d(data, **kwargs))
# TypeError: describe_boolean_1d() got an unexpected keyword argument 'title'
# """
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-331fda639ee9> in <module>
# ----> 1 profile = ProfileReport(dfNoNa, title='Pandas Profiling Report', explorative=True)
#
# ~\Anaconda3\envs\RPy\lib\site-packages\pandas_profiling\__init__.py in __init__(self, df, **kwargs)
#      64         sample = kwargs.get('sample', df.head())
#      65
# ---> 66         description_set = describe(df, **kwargs)
#      67
#      68         self.html = to_html(sample,
#
# ~\Anaconda3\envs\RPy\lib\site-packages\pandas_profiling\describe.py in describe(df, bins, check_correlation, correlation_threshold, correlation_overrides, check_recoded, pool_size, **kwargs)
#     349     pool = multiprocessing.Pool(pool_size)
#     350     local_multiprocess_func = partial(multiprocess_func, **kwargs)
# --> 351     ldesc = {col: s for col, s in pool.map(local_multiprocess_func, df.iteritems())}
#     352     pool.close()
#     353
#
# ~\Anaconda3\envs\RPy\lib\multiprocessing\pool.py in map(self, func, iterable, chunksize)
#     288         in a list that is returned.
#     289         '''
# --> 290         return self._map_async(func, iterable, mapstar, chunksize).get()
#     291
#     292     def starmap(self, func, iterable, chunksize=None):
#
# ~\Anaconda3\envs\RPy\lib\multiprocessing\pool.py in get(self, timeout)
#     681             return self._value
#     682         else:
# --> 683             raise self._value
#     684
#     685     def _set(self, i, obj):
#
# TypeError: describe_boolean_1d() got an unexpected keyword argument 'title'

# %%
profile
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-f9dbdb59857a> in <module>
# ----> 1 profile
#
# NameError: name 'profile' is not defined

# %%
# now divide the data into test and train using scikit learn built-ins
from sklearn.model_selection import StratifiedShuffleSplit 

cv = StratifiedShuffleSplit(n_splits=1,train_size=0.8)
print (cv)
# Out:
# StratifiedShuffleSplit(n_splits=1, random_state=None, test_size=None,
#             train_size=0.8)

# %%
features = ['isRe', 'underscore', 'priority', 'isInReplyTo',
       'sortedRec', 'subPunc', 'multipartText', 'hasImages', 'isPGPsigned',
       'subSpamWords', 'noHost', 'numEnd', 'isYelling', 'isOrigMsg', 'isDear',
       'isWrote', 'numLines', 'bodyCharCt', 'subExcCt', 'subQuesCt', 'numAtt',
       'numRec', 'perCaps', 'hour', 'perHTML', 'subBlanks', 'forwards',
       'avgWordLen', 'numDlr']

X = dfNoNa[features].copy()

#scaler = StandardScaler()
#scaler.fit(X2)

#This makes our model's coefficients take on the same scale for accurate feature importance analysis
#Notice we scaled the data before the cross validation
#X = scaler.transform(X2)

Y= dfNoNa[['isSpam']].copy()
y = Y.values

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split, GridSearchCV, KFold, TimeSeriesSplit, StratifiedShuffleSplit
from sklearn import metrics as mt
X1_train, X1_test, y1_train, y1_test = train_test_split(X, y, test_size = 0.2, random_state = 101)
dt_clf = DecisionTreeClassifier()
# %time dt_clf.fit(X1_train,y1_train)
yhat = dt_clf.predict(X1_test)
print ('accuracy:', mt.accuracy_score(y1_test,yhat))
# Out:
# Wall time: 68 ms
# accuracy: 0.9624101713653952

# %%
#grid search

# Create a dictionary of all the parameter options 
# Note has you can access the parameters of steps of a pipeline by using '__’
parameters ={'criterion':['gini','entropy'],
             'max_depth':[4,5,6,7,8,9,10,11,12,15,20,30,40,50,70,90,120,150],
             'min_samples_leaf': min_samples_leaf_range}}

# %%
dt_clf = GridSearchCV(DecisionTreeClassifier(), param_grid =parameters)

# train the decision tree algorithm
# %time dt_clf.fit(X1_train,y1_train)
yhat = dt_clf.best_estimator_.predict(X1_test)
print ('accuracy:', mt.accuracy_score(y1_test,yhat))
print (dt_clf.best_params_)
# Out:
# Wall time: 15.1 s
# accuracy: 0.9596462133775566
# {'criterion': 'gini', 'max_depth': 30}

# %% [markdown]
# Refit with the best params to use for ploting the tree viz

# %%
clf=DecisionTreeClassifier(**dt_clf.best_params_)
clf.fit(X1_train,y1_train)
yhat = clf.predict(X1_test)
print ('accuracy:', mt.accuracy_score(y1_test,yhat))
# Out:
# accuracy: 0.9585406301824212

# %%
from sklearn import tree
tree.plot_tree(clf);

# %% [markdown]
# Try and see if you cant get the cell below working. I have pydotplus installed but get not found.

# %%
import pydotplus
export_graphviz(clf, out_file=None,  
                filled=True, rounded=True,
                special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-78-f9b3ddd2e5f3> in <module>
# ----> 1 import pydotplus
#       2 export_graphviz(clf, out_file=None,
#       3                 filled=True, rounded=True,
#       4                 special_characters=True)
#       5 graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
#
# ModuleNotFoundError: No module named 'pydotplus'

# %%
import pydotplus
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-81-b7d16578ff11> in <module>
# ----> 1 import pydotplus
#
# ModuleNotFoundError: No module named 'pydotplus'

# %%
from sklearn.tree import export_graphviz

export_graphviz(**dt_clf.best_params_, out_file=None,  
                filled=True, rounded=True,
                special_characters=True)

tree.export_graphviz(clf,
                     out_file="tree.dot",
                     feature_names = fn, 
                     class_names=cn,
                     filled = True)
