# %% [markdown]
# ## ARIMA Walkthrough with flu data
#
# Load the data and plot it.  Note that to make the index a time object in python

# %%
import pandas as pd
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot as plt
import matplotlib 
# %matplotlib inline
 
data = read_csv(r'https://raw.githubusercontent.com/jjschueder/7333QTW/master/Case%20Study%204/NationalCombined_UpTo_2020.csv',sep=',')
print(data.head())
# Out:
#    Year  Week  PositiveCases
# 0  1997    40              0
# 1  1997    41             11
# 2  1997    42             17
# 3  1997    43              7
# 4  1997    44             10

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1185 entries, 0 to 1184
# Data columns (total 3 columns):
# Year             1185 non-null int64
# Week             1185 non-null int64
# PositiveCases    1185 non-null int64
# dtypes: int64(3)
# memory usage: 27.9 KB

# %%
data['Date'] = pd.to_datetime(data.Year.astype(str), format='%Y') + \
             pd.to_timedelta(data.Week.mul(7).astype(str) + ' days')


data = data.loc[data['Date'] >= '2015-07-01' ]
data = data.loc[data['Date'] < '2019-07-01']
data.index = pd.DatetimeIndex(data.Date).to_period('W')
#.to_period('W')#
data
# Out:
#                        Year  Week  PositiveCases       Date
# Date
# 2015-06-29/2015-07-05  2015    26            129 2015-07-02
# 2015-07-06/2015-07-12  2015    27             99 2015-07-09
# 2015-07-13/2015-07-19  2015    28             86 2015-07-16
# 2015-07-20/2015-07-26  2015    29             73 2015-07-23
# 2015-07-27/2015-08-02  2015    30             73 2015-07-30
# ...                     ...   ...            ...        ...
# 2019-05-27/2019-06-02  2019    21            669 2019-05-28
# 2019-06-03/2019-06-09  2019    22            581 2019-06-04
# 2019-06-10/2019-06-16  2019    23            487 2019-06-11
# 2019-06-17/2019-06-23  2019    24            376 2019-06-18
# 2019-06-24/2019-06-30  2019    25            294 2019-06-25
#
# [208 rows x 4 columns]

# %%
air_pop=data['PositiveCases']
#air_pop.index=pd.to_datetime(data['Date'])
#air_pop.index = pd.DatetimeIndex(air_pop.Date)
print(air_pop.head())
fig = plt.figure()

air_pop.plot()
plt.title("Flu")
plt.xlabel("Time")
plt.ylabel('Cases')
plt.show()
# Out:
# Date
# 2015-06-29/2015-07-05    129
# 2015-07-06/2015-07-12     99
# 2015-07-13/2015-07-19     86
# 2015-07-20/2015-07-26     73
# 2015-07-27/2015-08-02     73
# Freq: W-SUN, Name: PositiveCases, dtype: int64

# %% [markdown]
# This is just a function that implements the Dickey-Fuller test and plots data along with rolling mean and standard deviation

# %%
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries):
    
    #Determing rolling statistics
    rolmean = timeseries.rolling(52).mean()
    rolstd = timeseries.rolling(52).std()

    #Plot rolling statistics:
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
    #Perform Dickey-Fuller test:
    print('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

# %%
test_stationarity(air_pop)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-186-362deef93b27> in <module>
# ----> 1 test_stationarity(air_pop)
#
# <ipython-input-185-6492b9911774> in test_stationarity(timeseries)
#       7
#       8     #Plot rolling statistics:
# ----> 9     orig = plt.plot(timeseries, color='blue',label='Original')
#      10     mean = plt.plot(rolmean, color='red', label='Rolling Mean')
#      11     std = plt.plot(rolstd, color='black', label = 'Rolling Std')
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2763         is not None else {}), **kwargs)
#    2764
#    2765
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1644         """
#    1645         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1646         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1647         for line in lines:
#    1648             self.add_line(line)
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axes\_base.py in __call__(self, *args, **kwargs)
#     214                 this += args[0],
#     215                 args = args[1:]
# --> 216             yield from self._plot_args(this, kwargs)
#     217
#     218     def get_next_color(self):
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     335
#     336         if self.axes.xaxis is not None:
# --> 337             self.axes.xaxis.update_units(x)
#     338         if self.axes.yaxis is not None:
#     339             self.axes.yaxis.update_units(y)
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axis.py in update_units(self, data)
#    1519
#    1520         if neednew:
# -> 1521             self._update_axisinfo()
#    1522         self.stale = True
#    1523         return True
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axis.py in _update_axisinfo(self)
#    1555             self.isDefault_label = True
#    1556
# -> 1557         self.set_default_intervals()
#    1558
#    1559     def have_units(self):
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axis.py in set_default_intervals(self)
#    2177                 if info.default_limits is not None:
#    2178                     valmin, valmax = info.default_limits
# -> 2179                     xmin = self.converter.convert(valmin, self.units, self)
#    2180                     xmax = self.converter.convert(valmax, self.units, self)
#    2181             if not dataMutated:
#
# ~\.conda\envs\ML7331\lib\site-packages\pandas\plotting\_matplotlib\converter.py in convert(values, units, axis)
#     197             values = [PeriodConverter._convert_1d(v, units, axis) for v in values]
#     198         else:
# --> 199             values = PeriodConverter._convert_1d(values, units, axis)
#     200         return values
#     201
#
# ~\.conda\envs\ML7331\lib\site-packages\pandas\plotting\_matplotlib\converter.py in _convert_1d(values, units, axis)
#     203     def _convert_1d(values, units, axis):
#     204         if not hasattr(axis, "freq"):
# --> 205             raise TypeError("Axis must have `freq` set to convert to Periods")
#     206         valid_types = (str, datetime, Period, pydt.date, pydt.time, np.datetime64)
#     207         if isinstance(values, valid_types) or is_integer(values) or is_float(values):
#
# TypeError: Axis must have `freq` set to convert to Periods
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\.conda\envs\ML7331\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# ~\.conda\envs\ML7331\lib\site-packages\ipykernel\pylab\backend_inline.py in _fetch_figure_metadata(fig)
#     175         # the background is transparent
#     176         ticksLight = _is_light([label.get_color()
# --> 177                                 for axes in fig.axes
#     178                                 for axis in (axes.xaxis, axes.yaxis)
#     179                                 for label in axis.get_ticklabels()])
#
# ~\.conda\envs\ML7331\lib\site-packages\ipykernel\pylab\backend_inline.py in <listcomp>(.0)
#     177                                 for axes in fig.axes
#     178                                 for axis in (axes.xaxis, axes.yaxis)
# --> 179                                 for label in axis.get_ticklabels()])
#     180         if ticksLight.size and (ticksLight == ticksLight[0]).all():
#     181             # there are one or more tick labels, all with the same lightness
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axis.py in get_ticklabels(self, minor, which)
#    1318         if minor:
#    1319             return self.get_minorticklabels()
# -> 1320         return self.get_majorticklabels()
#    1321
#    1322     def get_majorticklines(self):
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axis.py in get_majorticklabels(self)
#    1274     def get_majorticklabels(self):
#    1275         'Return a list of Text instances for the major ticklabels.'
# -> 1276         ticks = self.get_major_ticks()
#    1277         labels1 = [tick.label1 for tick in ticks if tick.label1.get_visible()]
#    1278         labels2 = [tick.label2 for tick in ticks if tick.label2.get_visible()]
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axis.py in get_major_ticks(self, numticks)
#    1429         'Get the tick instances; grow as necessary.'
#    1430         if numticks is None:
# -> 1431             numticks = len(self.get_majorticklocs())
#    1432
#    1433         while len(self.majorTicks) < numticks:
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axis.py in get_majorticklocs(self)
#    1346     def get_majorticklocs(self):
#    1347         """Get the array of major tick locations in data coordinates."""
# -> 1348         return self.major.locator()
#    1349
#    1350     def get_minorticklocs(self):
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\dates.py in __call__(self)
#    1336     def __call__(self):
#    1337         'Return the locations of the ticks'
# -> 1338         self.refresh()
#    1339         return self._locator()
#    1340
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\dates.py in refresh(self)
#    1362     def refresh(self):
#    1363         # docstring inherited
# -> 1364         dmin, dmax = self.viewlim_to_dt()
#    1365         self._locator = self.get_locator(dmin, dmax)
#    1366
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\dates.py in viewlim_to_dt(self)
#    1096                              'often happens if you pass a non-datetime '
#    1097                              'value to an axis that has datetime units'
# -> 1098                              .format(vmin))
#    1099         return num2date(vmin, self.tz), num2date(vmax, self.tz)
#    1100
#
# ValueError: view limit minimum 0.0 is less than 1 and is an invalid Matplotlib date value. This often happens if you pass a non-datetime value to an axis that has datetime units

# %% [markdown]
# Now we will subtract the trend from our data to make it (more) stationary

# %%
moving_avg = air_pop.rolling(52).mean()
no_trend = air_pop - moving_avg
plt.plot(no_trend)
plt.title("Passenger Data with Rolling Mean Removed")
test_stationarity(no_trend.dropna())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-188-9282e5ddce00> in <module>
#       1 moving_avg = air_pop.rolling(52).mean()
#       2 no_trend = air_pop - moving_avg
# ----> 3 plt.plot(no_trend)
#       4 plt.title("Passenger Data with Rolling Mean Removed")
#       5 test_stationarity(no_trend.dropna())
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2763         is not None else {}), **kwargs)
#    2764
#    2765
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1644         """
#    1645         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1646         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1647         for line in lines:
#    1648             self.add_line(line)
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axes\_base.py in __call__(self, *args, **kwargs)
#     214                 this += args[0],
#     215                 args = args[1:]
# --> 216             yield from self._plot_args(this, kwargs)
#     217
#     218     def get_next_color(self):
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     335
#     336         if self.axes.xaxis is not None:
# --> 337             self.axes.xaxis.update_units(x)
#     338         if self.axes.yaxis is not None:
#     339             self.axes.yaxis.update_units(y)
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axis.py in update_units(self, data)
#    1519
#    1520         if neednew:
# -> 1521             self._update_axisinfo()
#    1522         self.stale = True
#    1523         return True
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axis.py in _update_axisinfo(self)
#    1555             self.isDefault_label = True
#    1556
# -> 1557         self.set_default_intervals()
#    1558
#    1559     def have_units(self):
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axis.py in set_default_intervals(self)
#    2177                 if info.default_limits is not None:
#    2178                     valmin, valmax = info.default_limits
# -> 2179                     xmin = self.converter.convert(valmin, self.units, self)
#    2180                     xmax = self.converter.convert(valmax, self.units, self)
#    2181             if not dataMutated:
#
# ~\.conda\envs\ML7331\lib\site-packages\pandas\plotting\_matplotlib\converter.py in convert(values, units, axis)
#     197             values = [PeriodConverter._convert_1d(v, units, axis) for v in values]
#     198         else:
# --> 199             values = PeriodConverter._convert_1d(values, units, axis)
#     200         return values
#     201
#
# ~\.conda\envs\ML7331\lib\site-packages\pandas\plotting\_matplotlib\converter.py in _convert_1d(values, units, axis)
#     203     def _convert_1d(values, units, axis):
#     204         if not hasattr(axis, "freq"):
# --> 205             raise TypeError("Axis must have `freq` set to convert to Periods")
#     206         valid_types = (str, datetime, Period, pydt.date, pydt.time, np.datetime64)
#     207         if isinstance(values, valid_types) or is_integer(values) or is_float(values):
#
# TypeError: Axis must have `freq` set to convert to Periods
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\.conda\envs\ML7331\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# ~\.conda\envs\ML7331\lib\site-packages\ipykernel\pylab\backend_inline.py in _fetch_figure_metadata(fig)
#     175         # the background is transparent
#     176         ticksLight = _is_light([label.get_color()
# --> 177                                 for axes in fig.axes
#     178                                 for axis in (axes.xaxis, axes.yaxis)
#     179                                 for label in axis.get_ticklabels()])
#
# ~\.conda\envs\ML7331\lib\site-packages\ipykernel\pylab\backend_inline.py in <listcomp>(.0)
#     177                                 for axes in fig.axes
#     178                                 for axis in (axes.xaxis, axes.yaxis)
# --> 179                                 for label in axis.get_ticklabels()])
#     180         if ticksLight.size and (ticksLight == ticksLight[0]).all():
#     181             # there are one or more tick labels, all with the same lightness
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axis.py in get_ticklabels(self, minor, which)
#    1318         if minor:
#    1319             return self.get_minorticklabels()
# -> 1320         return self.get_majorticklabels()
#    1321
#    1322     def get_majorticklines(self):
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axis.py in get_majorticklabels(self)
#    1274     def get_majorticklabels(self):
#    1275         'Return a list of Text instances for the major ticklabels.'
# -> 1276         ticks = self.get_major_ticks()
#    1277         labels1 = [tick.label1 for tick in ticks if tick.label1.get_visible()]
#    1278         labels2 = [tick.label2 for tick in ticks if tick.label2.get_visible()]
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axis.py in get_major_ticks(self, numticks)
#    1429         'Get the tick instances; grow as necessary.'
#    1430         if numticks is None:
# -> 1431             numticks = len(self.get_majorticklocs())
#    1432
#    1433         while len(self.majorTicks) < numticks:
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axis.py in get_majorticklocs(self)
#    1346     def get_majorticklocs(self):
#    1347         """Get the array of major tick locations in data coordinates."""
# -> 1348         return self.major.locator()
#    1349
#    1350     def get_minorticklocs(self):
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\dates.py in __call__(self)
#    1336     def __call__(self):
#    1337         'Return the locations of the ticks'
# -> 1338         self.refresh()
#    1339         return self._locator()
#    1340
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\dates.py in refresh(self)
#    1362     def refresh(self):
#    1363         # docstring inherited
# -> 1364         dmin, dmax = self.viewlim_to_dt()
#    1365         self._locator = self.get_locator(dmin, dmax)
#    1366
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\dates.py in viewlim_to_dt(self)
#    1096                              'often happens if you pass a non-datetime '
#    1097                              'value to an axis that has datetime units'
# -> 1098                              .format(vmin))
#    1099         return num2date(vmin, self.tz), num2date(vmax, self.tz)
#    1100
#
# ValueError: view limit minimum 0.0 is less than 1 and is an invalid Matplotlib date value. This often happens if you pass a non-datetime value to an axis that has datetime units

# %%
air_pop2 = pd.DataFrame(air_pop)
air_pop2
# Out:
#                        PositiveCases
# Date
# 2015-06-29/2015-07-05            129
# 2015-07-06/2015-07-12             99
# 2015-07-13/2015-07-19             86
# 2015-07-20/2015-07-26             73
# 2015-07-27/2015-08-02             73
# ...                              ...
# 2019-05-27/2019-06-02            669
# 2019-06-03/2019-06-09            581
# 2019-06-10/2019-06-16            487
# 2019-06-17/2019-06-23            376
# 2019-06-24/2019-06-30            294
#
# [208 rows x 1 columns]

# %% [markdown]
# Now we do a variable change from y to ln y.  Note that in python the "log" function is actually natural log, ln.  Also note that the test statistic did not change hardly at all, even though the series looks much better.
#
# In reality this data shows some seasonality, and there are seasonal models available, but for the purposes of the exercise we will ignore seasonality.

# %%
import numpy as np
log_air_pop=np.log(air_pop)
log_moving_avg = log_air_pop.rolling(52).mean()
log_no_trend=log_air_pop - log_moving_avg
test_stationarity(log_no_trend.dropna())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-190-2822739fdf78> in <module>
#       3 log_moving_avg = log_air_pop.rolling(52).mean()
#       4 log_no_trend=log_air_pop - log_moving_avg
# ----> 5 test_stationarity(log_no_trend.dropna())
#
# <ipython-input-185-6492b9911774> in test_stationarity(timeseries)
#       7
#       8     #Plot rolling statistics:
# ----> 9     orig = plt.plot(timeseries, color='blue',label='Original')
#      10     mean = plt.plot(rolmean, color='red', label='Rolling Mean')
#      11     std = plt.plot(rolstd, color='black', label = 'Rolling Std')
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2763         is not None else {}), **kwargs)
#    2764
#    2765
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1644         """
#    1645         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1646         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1647         for line in lines:
#    1648             self.add_line(line)
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axes\_base.py in __call__(self, *args, **kwargs)
#     214                 this += args[0],
#     215                 args = args[1:]
# --> 216             yield from self._plot_args(this, kwargs)
#     217
#     218     def get_next_color(self):
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     335
#     336         if self.axes.xaxis is not None:
# --> 337             self.axes.xaxis.update_units(x)
#     338         if self.axes.yaxis is not None:
#     339             self.axes.yaxis.update_units(y)
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axis.py in update_units(self, data)
#    1519
#    1520         if neednew:
# -> 1521             self._update_axisinfo()
#    1522         self.stale = True
#    1523         return True
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axis.py in _update_axisinfo(self)
#    1555             self.isDefault_label = True
#    1556
# -> 1557         self.set_default_intervals()
#    1558
#    1559     def have_units(self):
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axis.py in set_default_intervals(self)
#    2177                 if info.default_limits is not None:
#    2178                     valmin, valmax = info.default_limits
# -> 2179                     xmin = self.converter.convert(valmin, self.units, self)
#    2180                     xmax = self.converter.convert(valmax, self.units, self)
#    2181             if not dataMutated:
#
# ~\.conda\envs\ML7331\lib\site-packages\pandas\plotting\_matplotlib\converter.py in convert(values, units, axis)
#     197             values = [PeriodConverter._convert_1d(v, units, axis) for v in values]
#     198         else:
# --> 199             values = PeriodConverter._convert_1d(values, units, axis)
#     200         return values
#     201
#
# ~\.conda\envs\ML7331\lib\site-packages\pandas\plotting\_matplotlib\converter.py in _convert_1d(values, units, axis)
#     203     def _convert_1d(values, units, axis):
#     204         if not hasattr(axis, "freq"):
# --> 205             raise TypeError("Axis must have `freq` set to convert to Periods")
#     206         valid_types = (str, datetime, Period, pydt.date, pydt.time, np.datetime64)
#     207         if isinstance(values, valid_types) or is_integer(values) or is_float(values):
#
# TypeError: Axis must have `freq` set to convert to Periods
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\.conda\envs\ML7331\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# ~\.conda\envs\ML7331\lib\site-packages\ipykernel\pylab\backend_inline.py in _fetch_figure_metadata(fig)
#     175         # the background is transparent
#     176         ticksLight = _is_light([label.get_color()
# --> 177                                 for axes in fig.axes
#     178                                 for axis in (axes.xaxis, axes.yaxis)
#     179                                 for label in axis.get_ticklabels()])
#
# ~\.conda\envs\ML7331\lib\site-packages\ipykernel\pylab\backend_inline.py in <listcomp>(.0)
#     177                                 for axes in fig.axes
#     178                                 for axis in (axes.xaxis, axes.yaxis)
# --> 179                                 for label in axis.get_ticklabels()])
#     180         if ticksLight.size and (ticksLight == ticksLight[0]).all():
#     181             # there are one or more tick labels, all with the same lightness
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axis.py in get_ticklabels(self, minor, which)
#    1318         if minor:
#    1319             return self.get_minorticklabels()
# -> 1320         return self.get_majorticklabels()
#    1321
#    1322     def get_majorticklines(self):
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axis.py in get_majorticklabels(self)
#    1274     def get_majorticklabels(self):
#    1275         'Return a list of Text instances for the major ticklabels.'
# -> 1276         ticks = self.get_major_ticks()
#    1277         labels1 = [tick.label1 for tick in ticks if tick.label1.get_visible()]
#    1278         labels2 = [tick.label2 for tick in ticks if tick.label2.get_visible()]
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axis.py in get_major_ticks(self, numticks)
#    1429         'Get the tick instances; grow as necessary.'
#    1430         if numticks is None:
# -> 1431             numticks = len(self.get_majorticklocs())
#    1432
#    1433         while len(self.majorTicks) < numticks:
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axis.py in get_majorticklocs(self)
#    1346     def get_majorticklocs(self):
#    1347         """Get the array of major tick locations in data coordinates."""
# -> 1348         return self.major.locator()
#    1349
#    1350     def get_minorticklocs(self):
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\dates.py in __call__(self)
#    1336     def __call__(self):
#    1337         'Return the locations of the ticks'
# -> 1338         self.refresh()
#    1339         return self._locator()
#    1340
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\dates.py in refresh(self)
#    1362     def refresh(self):
#    1363         # docstring inherited
# -> 1364         dmin, dmax = self.viewlim_to_dt()
#    1365         self._locator = self.get_locator(dmin, dmax)
#    1366
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\dates.py in viewlim_to_dt(self)
#    1096                              'often happens if you pass a non-datetime '
#    1097                              'value to an axis that has datetime units'
# -> 1098                              .format(vmin))
#    1099         return num2date(vmin, self.tz), num2date(vmax, self.tz)
#    1100
#
# ValueError: view limit minimum 0.0 is less than 1 and is an invalid Matplotlib date value. This often happens if you pass a non-datetime value to an axis that has datetime units

# %%
air_pop.describe()
# Out:
# count      208.000000
# mean      3836.038462
# std       5899.379622
# min         73.000000
# 25%        215.500000
# 50%        729.000000
# 75%       5725.500000
# max      26386.000000
# Name: PositiveCases, dtype: float64

# %%
air_pop
# Out:
# Date
# 2015-07-02    129
# 2015-07-09     99
# 2015-07-16     86
# 2015-07-23     73
# 2015-07-30     73
#              ...
# 2019-05-28    669
# 2019-06-04    581
# 2019-06-11    487
# 2019-06-18    376
# 2019-06-25    294
# Name: PositiveCases, Length: 208, dtype: int64

# %% [markdown]
# This next set of charts simply shows all the pieces of the function.  Note that while it does include seasonality, there still seems to be residual seasonality in the residuals.

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(air_pop, model='additive',freq = 52)

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid
plt.figure(num=None, figsize=(8, 10), dpi=80, facecolor='w', edgecolor='k')
plt.subplot(411)
plt.plot(air_pop, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-191-154818d2739f> in <module>
#       7 plt.figure(num=None, figsize=(8, 10), dpi=80, facecolor='w', edgecolor='k')
#       8 plt.subplot(411)
# ----> 9 plt.plot(air_pop, label='Original')
#      10 plt.legend(loc='best')
#      11 plt.subplot(412)
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2763         is not None else {}), **kwargs)
#    2764
#    2765
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1644         """
#    1645         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1646         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1647         for line in lines:
#    1648             self.add_line(line)
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axes\_base.py in __call__(self, *args, **kwargs)
#     214                 this += args[0],
#     215                 args = args[1:]
# --> 216             yield from self._plot_args(this, kwargs)
#     217
#     218     def get_next_color(self):
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     335
#     336         if self.axes.xaxis is not None:
# --> 337             self.axes.xaxis.update_units(x)
#     338         if self.axes.yaxis is not None:
#     339             self.axes.yaxis.update_units(y)
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axis.py in update_units(self, data)
#    1519
#    1520         if neednew:
# -> 1521             self._update_axisinfo()
#    1522         self.stale = True
#    1523         return True
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axis.py in _update_axisinfo(self)
#    1555             self.isDefault_label = True
#    1556
# -> 1557         self.set_default_intervals()
#    1558
#    1559     def have_units(self):
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axis.py in set_default_intervals(self)
#    2177                 if info.default_limits is not None:
#    2178                     valmin, valmax = info.default_limits
# -> 2179                     xmin = self.converter.convert(valmin, self.units, self)
#    2180                     xmax = self.converter.convert(valmax, self.units, self)
#    2181             if not dataMutated:
#
# ~\.conda\envs\ML7331\lib\site-packages\pandas\plotting\_matplotlib\converter.py in convert(values, units, axis)
#     197             values = [PeriodConverter._convert_1d(v, units, axis) for v in values]
#     198         else:
# --> 199             values = PeriodConverter._convert_1d(values, units, axis)
#     200         return values
#     201
#
# ~\.conda\envs\ML7331\lib\site-packages\pandas\plotting\_matplotlib\converter.py in _convert_1d(values, units, axis)
#     203     def _convert_1d(values, units, axis):
#     204         if not hasattr(axis, "freq"):
# --> 205             raise TypeError("Axis must have `freq` set to convert to Periods")
#     206         valid_types = (str, datetime, Period, pydt.date, pydt.time, np.datetime64)
#     207         if isinstance(values, valid_types) or is_integer(values) or is_float(values):
#
# TypeError: Axis must have `freq` set to convert to Periods
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\.conda\envs\ML7331\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~\.conda\envs\ML7331\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~\.conda\envs\ML7331\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2077                             print_method, dpi=dpi, orientation=orientation),
#    2078                         draw_disabled=True)
# -> 2079                     self.figure.draw(renderer)
#    2080                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#    2081                     bbox_inches = self.figure.get_tightbbox(renderer,
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1734             self.patch.draw(renderer)
#    1735             mimage._draw_list_compositing_images(
# -> 1736                 renderer, self, artists, self.suppressComposite)
#    1737
#    1738             renderer.close_group('figure')
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     135     if not_composite or not has_images:
#     136         for a in artists:
# --> 137             a.draw(renderer)
#     138     else:
#     139         # Composite any adjacent images together
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2628             renderer.stop_rasterizing()
#    2629
# -> 2630         mimage._draw_list_compositing_images(renderer, self, artists)
#    2631
#    2632         renderer.close_group('axes')
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     135     if not_composite or not has_images:
#     136         for a in artists:
# --> 137             a.draw(renderer)
#     138     else:
#     139         # Composite any adjacent images together
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axis.py in draw(self, renderer, *args, **kwargs)
#    1225         renderer.open_group(__name__, gid=self.get_gid())
#    1226
# -> 1227         ticks_to_draw = self._update_ticks()
#    1228         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1229                                                                 renderer)
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axis.py in _update_ticks(self)
#    1101         the axes.  Return the list of ticks that will be drawn.
#    1102         """
# -> 1103         major_locs = self.get_majorticklocs()
#    1104         major_labels = self.major.formatter.format_ticks(major_locs)
#    1105         major_ticks = self.get_major_ticks(len(major_locs))
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axis.py in get_majorticklocs(self)
#    1346     def get_majorticklocs(self):
#    1347         """Get the array of major tick locations in data coordinates."""
# -> 1348         return self.major.locator()
#    1349
#    1350     def get_minorticklocs(self):
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\dates.py in __call__(self)
#    1336     def __call__(self):
#    1337         'Return the locations of the ticks'
# -> 1338         self.refresh()
#    1339         return self._locator()
#    1340
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\dates.py in refresh(self)
#    1362     def refresh(self):
#    1363         # docstring inherited
# -> 1364         dmin, dmax = self.viewlim_to_dt()
#    1365         self._locator = self.get_locator(dmin, dmax)
#    1366
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\dates.py in viewlim_to_dt(self)
#    1096                              'often happens if you pass a non-datetime '
#    1097                              'value to an axis that has datetime units'
# -> 1098                              .format(vmin))
#    1099         return num2date(vmin, self.tz), num2date(vmax, self.tz)
#    1100
#
# ValueError: view limit minimum 0.0 is less than 1 and is an invalid Matplotlib date value. This often happens if you pass a non-datetime value to an axis that has datetime units

# %% [markdown]
# Next we will try some differencing to try and eliminate seasonality and make the series further stationary.  This determines if we use a difference term or not.  In this example, 1 shift ($y_t - y_{t-1}$) is used, so d=1

# %%
diff_air_pop = log_air_pop-log_air_pop.shift(1) # Changing the shift value is equivalent to changing your 'd' value
test_stationarity(diff_air_pop.dropna())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-192-4dd3613c5c62> in <module>
#       1 diff_air_pop = log_air_pop-log_air_pop.shift(1) # Changing the shift value is equivalent to changing your 'd' value
# ----> 2 test_stationarity(diff_air_pop.dropna())
#
# <ipython-input-185-6492b9911774> in test_stationarity(timeseries)
#       7
#       8     #Plot rolling statistics:
# ----> 9     orig = plt.plot(timeseries, color='blue',label='Original')
#      10     mean = plt.plot(rolmean, color='red', label='Rolling Mean')
#      11     std = plt.plot(rolstd, color='black', label = 'Rolling Std')
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2763         is not None else {}), **kwargs)
#    2764
#    2765
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1644         """
#    1645         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1646         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1647         for line in lines:
#    1648             self.add_line(line)
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axes\_base.py in __call__(self, *args, **kwargs)
#     214                 this += args[0],
#     215                 args = args[1:]
# --> 216             yield from self._plot_args(this, kwargs)
#     217
#     218     def get_next_color(self):
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     335
#     336         if self.axes.xaxis is not None:
# --> 337             self.axes.xaxis.update_units(x)
#     338         if self.axes.yaxis is not None:
#     339             self.axes.yaxis.update_units(y)
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axis.py in update_units(self, data)
#    1519
#    1520         if neednew:
# -> 1521             self._update_axisinfo()
#    1522         self.stale = True
#    1523         return True
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axis.py in _update_axisinfo(self)
#    1555             self.isDefault_label = True
#    1556
# -> 1557         self.set_default_intervals()
#    1558
#    1559     def have_units(self):
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axis.py in set_default_intervals(self)
#    2177                 if info.default_limits is not None:
#    2178                     valmin, valmax = info.default_limits
# -> 2179                     xmin = self.converter.convert(valmin, self.units, self)
#    2180                     xmax = self.converter.convert(valmax, self.units, self)
#    2181             if not dataMutated:
#
# ~\.conda\envs\ML7331\lib\site-packages\pandas\plotting\_matplotlib\converter.py in convert(values, units, axis)
#     197             values = [PeriodConverter._convert_1d(v, units, axis) for v in values]
#     198         else:
# --> 199             values = PeriodConverter._convert_1d(values, units, axis)
#     200         return values
#     201
#
# ~\.conda\envs\ML7331\lib\site-packages\pandas\plotting\_matplotlib\converter.py in _convert_1d(values, units, axis)
#     203     def _convert_1d(values, units, axis):
#     204         if not hasattr(axis, "freq"):
# --> 205             raise TypeError("Axis must have `freq` set to convert to Periods")
#     206         valid_types = (str, datetime, Period, pydt.date, pydt.time, np.datetime64)
#     207         if isinstance(values, valid_types) or is_integer(values) or is_float(values):
#
# TypeError: Axis must have `freq` set to convert to Periods
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\.conda\envs\ML7331\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# ~\.conda\envs\ML7331\lib\site-packages\ipykernel\pylab\backend_inline.py in _fetch_figure_metadata(fig)
#     175         # the background is transparent
#     176         ticksLight = _is_light([label.get_color()
# --> 177                                 for axes in fig.axes
#     178                                 for axis in (axes.xaxis, axes.yaxis)
#     179                                 for label in axis.get_ticklabels()])
#
# ~\.conda\envs\ML7331\lib\site-packages\ipykernel\pylab\backend_inline.py in <listcomp>(.0)
#     177                                 for axes in fig.axes
#     178                                 for axis in (axes.xaxis, axes.yaxis)
# --> 179                                 for label in axis.get_ticklabels()])
#     180         if ticksLight.size and (ticksLight == ticksLight[0]).all():
#     181             # there are one or more tick labels, all with the same lightness
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axis.py in get_ticklabels(self, minor, which)
#    1318         if minor:
#    1319             return self.get_minorticklabels()
# -> 1320         return self.get_majorticklabels()
#    1321
#    1322     def get_majorticklines(self):
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axis.py in get_majorticklabels(self)
#    1274     def get_majorticklabels(self):
#    1275         'Return a list of Text instances for the major ticklabels.'
# -> 1276         ticks = self.get_major_ticks()
#    1277         labels1 = [tick.label1 for tick in ticks if tick.label1.get_visible()]
#    1278         labels2 = [tick.label2 for tick in ticks if tick.label2.get_visible()]
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axis.py in get_major_ticks(self, numticks)
#    1429         'Get the tick instances; grow as necessary.'
#    1430         if numticks is None:
# -> 1431             numticks = len(self.get_majorticklocs())
#    1432
#    1433         while len(self.majorTicks) < numticks:
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axis.py in get_majorticklocs(self)
#    1346     def get_majorticklocs(self):
#    1347         """Get the array of major tick locations in data coordinates."""
# -> 1348         return self.major.locator()
#    1349
#    1350     def get_minorticklocs(self):
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\dates.py in __call__(self)
#    1336     def __call__(self):
#    1337         'Return the locations of the ticks'
# -> 1338         self.refresh()
#    1339         return self._locator()
#    1340
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\dates.py in refresh(self)
#    1362     def refresh(self):
#    1363         # docstring inherited
# -> 1364         dmin, dmax = self.viewlim_to_dt()
#    1365         self._locator = self.get_locator(dmin, dmax)
#    1366
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\dates.py in viewlim_to_dt(self)
#    1096                              'often happens if you pass a non-datetime '
#    1097                              'value to an axis that has datetime units'
# -> 1098                              .format(vmin))
#    1099         return num2date(vmin, self.tz), num2date(vmax, self.tz)
#    1100
#
# ValueError: view limit minimum 0.0 is less than 1 and is an invalid Matplotlib date value. This often happens if you pass a non-datetime value to an axis that has datetime units

# %% [markdown]
# Now we take a look at the Autocorrelation and Partial Autocorrelation plots

# %%
from statsmodels.tsa.stattools import acf, pacf
acf_air_plot = acf(air_pop.dropna(), nlags=20, fft=True)
#Plot ACF: 
plt.figure(figsize=(20, 4))

plt.subplot(121) 
plt.plot(acf_air_plot)
plt.xticks(np.arange(21))
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(acf_air_plot)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(acf_air_plot)),linestyle='--',color='gray')
for i in range(1,20):
    plt.axvline(x=i,linestyle=':',color='gray')
plt.title('Autocorrelation Function')
# Out:
# Text(0.5, 1.0, 'Autocorrelation Function')

# %%
pacf_air_plot = pacf(air_pop2.dropna(), nlags=20)
#Plot ACF: 
plt.figure(figsize=(20, 4))

plt.subplot(121) 
plt.plot(pacf_air_plot)
plt.xticks(np.arange(21))
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(acf_air_plot)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(acf_air_plot)),linestyle='--',color='gray')
for i in range(1,20):
    plt.axvline(x=i,linestyle=':',color='gray')
plt.title('Partial Autocorrelation Function')
# Out:
# C:\Users\jjsch\.conda\envs\ML7331\lib\site-packages\statsmodels\regression\linear_model.py:1358: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)
# Text(0.5, 1.0, 'Partial Autocorrelation Function')

# %%
from statsmodels.tsa.stattools import acf, pacf
acf_air_plot = acf(diff_air_pop.dropna(), nlags=20, fft=True)
#Plot ACF: 
plt.figure(figsize=(20, 4))

plt.subplot(121) 
plt.plot(acf_air_plot)
plt.xticks(np.arange(21))
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(acf_air_plot)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(acf_air_plot)),linestyle='--',color='gray')
for i in range(1,20):
    plt.axvline(x=i,linestyle=':',color='gray')
plt.title('Autocorrelation Function')
# Out:
# Text(0.5, 1.0, 'Autocorrelation Function')

# %%
pacf_air_plot = pacf(diff_air_pop.dropna(), nlags=20)
#Plot ACF: 
plt.figure(figsize=(20, 4))

plt.subplot(121) 
plt.plot(pacf_air_plot)
plt.xticks(np.arange(21))
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(acf_air_plot)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(acf_air_plot)),linestyle='--',color='gray')
for i in range(1,20):
    plt.axvline(x=i,linestyle=':',color='gray')
plt.title('Partial Autocorrelation Function')
# Out:
# Text(0.5, 1.0, 'Partial Autocorrelation Function')

# %% [markdown]
# Now we fit a model of the proper order and look at the output

# %% [markdown]
# **Since both the Autocorrelation and Partial Autocorrelation plots showed a drop at Lag 1 to within our confidence ranges - we'll start with a (1,0,1) ARIMA model.**  A (1,0,0) would likely fit equally well.

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
diff_air_pop = diff_air_pop.dropna()

# %%
diff_air_popdf = pd.DataFrame(diff_air_pop)
diff_air_popdf.to_csv(r'C:\Users\jjsch\Documents\airpop.csv')
diff_air_popdf
# Out:
#                        PositiveCases
# Date
# 2015-07-06/2015-07-12      -0.264693
# 2015-07-13/2015-07-19      -0.140773
# 2015-07-20/2015-07-26      -0.163888
# 2015-07-27/2015-08-02       0.000000
# 2015-08-03/2015-08-09       0.242140
# ...                              ...
# 2019-05-27/2019-06-02      -0.163714
# 2019-06-03/2019-06-09      -0.141033
# 2019-06-10/2019-06-16      -0.176487
# 2019-06-17/2019-06-23      -0.258675
# 2019-06-24/2019-06-30      -0.246009
#
# [207 rows x 1 columns]

# %%
model = ARIMA(diff_air_popdf.dropna(), order=(1,0,1), freq='W') 
#W stands for week
# MS stands for 'Month Start' in time series frequencies
model_fit = model.fit(disp=0)
print(model_fit.summary())
# plot residual errors
residuals = pd.DataFrame(model_fit.resid)
residuals.plot()
plt.show()
residuals.plot(kind='kde')
plt.show()
print(residuals.describe())
# Out:
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:          PositiveCases   No. Observations:                  207
# Model:                     ARMA(1, 1)   Log Likelihood                  69.392
# Method:                       css-mle   S.D. of innovations              0.173
# Date:                Sun, 28 Jun 2020   AIC                           -130.784
# Time:                        15:56:37   BIC                           -117.453
# Sample:                    07-12-2015   HQIC                          -125.393
#                          - 06-30-2019
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                  -0.0139      0.070     -0.199      0.842      -0.151       0.123
# ar.L1.PositiveCases     0.9105      0.034     26.433      0.000       0.843       0.978
# ma.L1.PositiveCases    -0.4572      0.068     -6.699      0.000      -0.591      -0.323
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0983           +0.0000j            1.0983            0.0000
# MA.1            2.1873           +0.0000j            2.1873            0.0000
# -----------------------------------------------------------------------------
#                 0
# count  207.000000
# mean     0.001854
# std      0.173561
# min     -0.499382
# 25%     -0.112222
# 50%      0.006323
# 75%      0.097206
# max      0.713174

# %% [markdown]
# Above we used a predifferenced dataset, below, we can use the log transformed dataset (allowing ARIMA to handle the differencing within the modeling process; where d = 1)

# %%
model2 = ARIMA(log_air_pop.dropna(), order=(1,1,1), freq='W') # MS stands for 'Month Start' in time series frequencies
model2_fit = model2.fit(disp=0)
print(model2_fit.summary())
# plot residual errors
residuals2 = pd.DataFrame(model2_fit.resid)
residuals2.plot()
plt.show()
residuals2.plot(kind='kde')
plt.show()
print(residuals2.describe())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:        D.PositiveCases   No. Observations:                  207
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                  69.392
# Method:                       css-mle   S.D. of innovations              0.173
# Date:                Sun, 28 Jun 2020   AIC                           -130.784
# Time:                        15:57:10   BIC                           -117.453
# Sample:                    07-12-2015   HQIC                          -125.393
#                          - 06-30-2019
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -0.0139      0.070     -0.199      0.842      -0.151       0.123
# ar.L1.D.PositiveCases     0.9105      0.034     26.433      0.000       0.843       0.978
# ma.L1.D.PositiveCases    -0.4572      0.068     -6.699      0.000      -0.591      -0.323
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0983           +0.0000j            1.0983            0.0000
# MA.1            2.1873           +0.0000j            2.1873            0.0000
# -----------------------------------------------------------------------------
#                 0
# count  207.000000
# mean     0.001854
# std      0.173561
# min     -0.499382
# 25%     -0.112222
# 50%      0.006323
# 75%      0.097206
# max      0.713174

# %% [markdown]
# **That bi-modal density is not the best - we may need some differencing!**

# %%
air_pop[-49:].plot()

# %%
diff_air_pop
# Out:
# Date
# 2015-07-02         NaN
# 2015-07-09   -0.264693
# 2015-07-16   -0.140773
# 2015-07-23   -0.163888
# 2015-07-30    0.000000
#                 ...
# 2019-05-28   -0.163714
# 2019-06-04   -0.141033
# 2019-06-11   -0.176487
# 2019-06-18   -0.258675
# 2019-06-25   -0.246009
# Name: PositiveCases, Length: 208, dtype: float64

# %% [markdown]
# Now I am just going to do a brute force search for parameters and find the best  ones.

# %%
air_pop = air_pop.astype(float)
loss_best = 1E16
best_ints = [-1,-1,-1]
for p in range(4):
    for d in range(3):
        for q in range(3):
            model = ARIMA(diff_air_pop.dropna(), order=(p, d, q), freq='W')  
            try:
                results_ARIMA = model.fit(disp=-1)
            except ValueError:
                pass
            except:
                pass
 #           plt.plot(diff_air_pop)
 #           plt.plot(results_ARIMA.fittedvalues, color='red')
            x=pd.DataFrame(results_ARIMA.fittedvalues)
            x=x.join(diff_air_pop)
            x['out']=(x.iloc[:,0]-x.iloc[:,1])**2
            loss=np.sqrt(x['out'].sum())
 #           plt.title('RSS: %.4f'% loss)
            if loss < loss_best:
                print(loss)
                loss_best = loss
                best_ints=[p,d,q]
  #          plt.show()
            print(p,d,q)
# Out:
# 3.6904180234456327
# 0 0 0
# 3.155946257373573
# 0 0 1
# 2.7385944369447093
# 0 0 2
# 0 1 0
# 0 1 1
# 0 1 2
# 0 2 0
# 0 2 1
# 0 2 2
# 2.6780085629754407
# 1 0 0
# 2.4912138701445046
# 1 0 1
# 2.47274009480065
# 1 0 2
# 1 1 0
# 1 1 1
# 1 1 2
# 1 2 0
# 1 2 1
# 1 2 2
# 2.4600604364331757
# 2 0 0
# 2.4596911067480773
# 2 0 1
# 2.4589183767399856
# 2 0 2
# 2 1 0
# 2 1 1
# 2 1 2
# 2 2 0
# 2 2 1
# C:\Users\jjsch\.conda\envs\ML7331\lib\site-packages\statsmodels\base\model.py:492: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
# 2 2 2
# 3 0 0
# 2.458355904580876
# 3 0 1
# 2.4574723629524753
# 3 0 2
# 3 1 0
# 3 1 1
# 3 1 2
# 3 2 0
# 3 2 1
# 3 2 2

# %%
best_ints
# Out:
# [3, 0, 2]

# %%
loss_best
# Out:
# 2.4574723629524753

# %%
air_pop = air_pop.astype(float)
loss_best = 1E16
best_ints = [-1,-1,-1]
for p in range(4):
    for d in range(3):
        for q in range(3):
            model = ARIMA(air_pop.dropna(), order=(p, d, q))
            #, freq='MS')  
            try:
                results_ARIMA = model.fit(disp=-1)
            except ValueError:
                pass
            except:
                pass
 #           plt.plot(air_pop)
 #           plt.plot(results_ARIMA.fittedvalues, color='red')
            x=pd.DataFrame(results_ARIMA.fittedvalues)
            x=x.join(air_pop)
            x['out']=(x.iloc[:,0]-x.iloc[:,1])**2
            loss=np.sqrt(x['out'].sum())
#            plt.title('RSS: %.4f'% loss)
            if loss < loss_best:
                print(loss)
                loss_best = loss
                best_ints=[p,d,q]
 #           plt.show()
            print(p,d,q)
# Out:
# 84877.29227356578
# 0 0 0
# 45636.38816841655
# 0 0 1
# 0 0 2
# 0 1 0
# 0 1 1
# 0 1 2
# 0 2 0
# 0 2 1
# 0 2 2
# 19583.6625747748
# 1 0 0
# 15914.693010967463
# 1 0 1
# 14311.477333719742
# 1 0 2
# 1 1 0
# 1 1 1
# 1 1 2
# 1 2 0
# 1 2 1
# 1 2 2
# 13970.71429311955
# 2 0 0
# 13944.877881511287
# 2 0 1
# 13727.90422231253
# 2 0 2
# 2 1 0
# 2 1 1
# 2 1 2
# 2 2 0
# 2 2 1
# 2 2 2
# 3 0 0
# 3 0 1
# 3 0 2
# 3 1 0
# 3 1 1
# 3 1 2
# 3 2 0
# 3 2 1
# 3 2 2

# %%
print(loss_best)
print(best_ints)
# Out:
# 13727.90422231253
# [2, 0, 2]

# %% [markdown]
# **Is this the best answer?  Why or why not?**

# %%
import statsmodels.api as sm
air_pop = air_pop.astype(float)
loss_best = 1E16
best_ints = [-1,-1,-1]
for p in range(4):
    for d in range(3):
        for q in range(3):
            model = sm.tsa.statespace.SARIMAX(air_pop.dropna(), order=(p, d, q), 
                            seasonal_order=(3, 0, 0, 52,),
                            enforce_stationarity=False,
                            enforce_invertibility=False)
            #, freq='MS')  
            try:
                results_ARIMA = model.fit(disp=-1)
            except ValueError:
                pass
            except:
                pass
 #           plt.plot(air_pop)
 #           plt.plot(results_ARIMA.fittedvalues, color='red')
            x=pd.DataFrame(results_ARIMA.fittedvalues)
            x=x.join(air_pop)
            x['out']=(x.iloc[:,0]-x.iloc[:,1])**2
            loss=np.sqrt(x['out'].sum())
#            plt.title('RSS: %.4f'% loss)
            if loss < loss_best:
                print(loss)
                loss_best = loss
                best_ints=[p,d,q]
 #           plt.show()
            print(p,d,q)
# Out:
# 75308.81345611354
# 0 0 0
# C:\Users\jjsch\.conda\envs\ML7331\lib\site-packages\statsmodels\base\model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 65035.203782388446
# 0 0 1
# C:\Users\jjsch\.conda\envs\ML7331\lib\site-packages\statsmodels\base\model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 57447.16055077548
# 0 0 2
# 18286.418542046402
# 0 1 0
# 0 1 1
# C:\Users\jjsch\.conda\envs\ML7331\lib\site-packages\statsmodels\base\model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 17197.498392288155
# 0 1 2
# 15260.369367108799
# 0 2 0
# 0 2 1
# 15238.9393391268
# 0 2 2
# 1 0 0
# 1 0 1
# C:\Users\jjsch\.conda\envs\ML7331\lib\site-packages\statsmodels\base\model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 1 0 2
# 1 1 0
# 14978.484463964105
# 1 1 1
# C:\Users\jjsch\.conda\envs\ML7331\lib\site-packages\statsmodels\base\model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 1 1 2
# 1 2 0
# 1 2 1
# C:\Users\jjsch\.conda\envs\ML7331\lib\site-packages\statsmodels\base\model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 1 2 2
# 2 0 0
# C:\Users\jjsch\.conda\envs\ML7331\lib\site-packages\statsmodels\base\model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 2 0 1
# C:\Users\jjsch\.conda\envs\ML7331\lib\site-packages\statsmodels\base\model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 2 0 2
# 2 1 0
# C:\Users\jjsch\.conda\envs\ML7331\lib\site-packages\statsmodels\base\model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 2 1 1
# C:\Users\jjsch\.conda\envs\ML7331\lib\site-packages\statsmodels\base\model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 2 1 2
# 2 2 0
# C:\Users\jjsch\.conda\envs\ML7331\lib\site-packages\statsmodels\base\model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 2 2 1
# C:\Users\jjsch\.conda\envs\ML7331\lib\site-packages\statsmodels\base\model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 2 2 2
# 3 0 0
# 3 0 1
# C:\Users\jjsch\.conda\envs\ML7331\lib\site-packages\statsmodels\base\model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 3 0 2
# 3 1 0
# C:\Users\jjsch\.conda\envs\ML7331\lib\site-packages\statsmodels\base\model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 14758.510317376806
# 3 1 1
# C:\Users\jjsch\.conda\envs\ML7331\lib\site-packages\statsmodels\base\model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 3 1 2
# 3 2 0
# 3 2 1
# 3 2 2

# %%
mod = sm.tsa.statespace.SARIMAX(no_trend.dropna(),
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)
            results = mod.fit()

# %% [markdown]
# No, it violates RULES 8.  With an AR (p) of 3, your MA (q) must be 1 or 0.  You might need to write a function to eliminate these scenarios from your "best" list.

# %% [markdown]
# ## Stock Prices with ARIMA

# %%
import datetime
pd.core.common.is_list_like = pd.api.types.is_list_like
from pandas_datareader import data as web
start = datetime.datetime(2015, 10, 1)
end = datetime.datetime(2020, 2, 1)
# Change 'iex' to 'yahoo' and capitalize 'close'
#price = web.DataReader('FOSL', 'yahoo', start, end)['Close']
price = data
price.index = pd.DatetimeIndex(price.Date)
df.index.dt.day

# %%
price
# Out:
#             Year  Week  PositiveCases       Date   datetime
# Date
# 2015-07-02  2015    26            129 2015-07-02 2015-07-02
# 2015-07-09  2015    27             99 2015-07-09 2015-07-09
# 2015-07-16  2015    28             86 2015-07-16 2015-07-16
# 2015-07-23  2015    29             73 2015-07-23 2015-07-23
# 2015-07-30  2015    30             73 2015-07-30 2015-07-30
# ...          ...   ...            ...        ...        ...
# 2019-05-28  2019    21            669 2019-05-28 2019-05-28
# 2019-06-04  2019    22            581 2019-06-04 2019-06-04
# 2019-06-11  2019    23            487 2019-06-11 2019-06-11
# 2019-06-18  2019    24            376 2019-06-18 2019-06-18
# 2019-06-25  2019    25            294 2019-06-25 2019-06-25
#
# [208 rows x 5 columns]

# %%
max(price.index)
# Out:
# Timestamp('2019-06-25 00:00:00')

# %%
price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 208 entries, 2015-07-02 to 2019-06-25
# Data columns (total 5 columns):
# Year             208 non-null int64
# Week             208 non-null int64
# PositiveCases    208 non-null int64
# Date             208 non-null datetime64[ns]
# datetime         208 non-null datetime64[ns]
# dtypes: datetime64[ns](2), int64(3)
# memory usage: 9.8 KB

# %%
max(price.PositiveCases)
# Out:
# 26386

# %%
min(price.PositiveCases)
# Out:
# 73

# %%
plt.plot(price.PositiveCases)

# %%
def test_stationarity(timeseries):
    
    #Determing rolling statistics
    rolmean = timeseries.rolling(30).mean()
    rolstd = timeseries.rolling(30).std()

    #Plot rolling statistics:
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
    #Perform Dickey-Fuller test:
    print('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

# %%
test_stationarity(price)
# Out:
# Results of Dickey-Fuller Test:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-149-71597d5628c8> in <module>
# ----> 1 test_stationarity(price)
#
# <ipython-input-148-b860dd7a4dce> in test_stationarity(timeseries)
#      15     #Perform Dickey-Fuller test:
#      16     print('Results of Dickey-Fuller Test:')
# ---> 17     dftest = adfuller(timeseries, autolag='AIC')
#      18     dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
#      19     for key,value in dftest[4].items():
#
# ~\.conda\envs\ML7331\lib\site-packages\statsmodels\tsa\stattools.py in adfuller(x, maxlag, regression, autolag, store, regresults)
#     233                          'where n trend is the number of included '
#     234                          'deterministic regressors')
# --> 235     xdiff = np.diff(x)
#     236     xdall = lagmat(xdiff[:, None], maxlag, trim='both', original='in')
#     237     nobs = xdall.shape[0]
#
# <__array_function__ internals> in diff(*args, **kwargs)
#
# ~\.conda\envs\ML7331\lib\site-packages\numpy\lib\function_base.py in diff(a, n, axis, prepend, append)
#    1271     op = not_equal if a.dtype == np.bool_ else subtract
#    1272     for _ in range(n):
# -> 1273         a = op(a[slice1], a[slice2])
#    1274
#    1275     return a
#
# pandas/_libs/tslibs/c_timestamp.pyx in pandas._libs.tslibs.c_timestamp._Timestamp.__sub__()
#
# pandas/_libs/tslibs/c_timestamp.pyx in pandas._libs.tslibs.c_timestamp._Timestamp.__add__()
#
# ValueError: Cannot add integral value to Timestamp without freq.

# %%
diff=price-price.shift(1)
diff.dropna(inplace=True)
diff.plot()
test_stationarity(diff)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -31.840171
# p-value                           0.000000
# #Lags Used                        0.000000
# Number of Observations Used    1089.000000
# Critical Value (1%)              -3.436369
# Critical Value (5%)              -2.864198
# Critical Value (10%)             -2.568185
# dtype: float64

# %% [markdown]
# ### Without differencing, your Autocorrelation Plot looks like this:

# %%
acf_stock_plot = acf(price, nlags=20, fft=True)
#Plot ACF: 
plt.figure(figsize=(20, 4))

plt.subplot(121) 
plt.plot(acf_stock_plot)
plt.xticks(np.arange(21))
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(acf_stock_plot)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(acf_stock_plot)),linestyle='--',color='gray')
for i in range(1,20):
    plt.axvline(x=i,linestyle=':',color='gray')
plt.title('Autocorrelation Function')
# Out:
# Text(0.5, 1.0, 'Autocorrelation Function')

# %%
pacf_stock_plot = pacf(price, nlags=20)
#Plot PACF: 
plt.figure(figsize=(20, 4))

plt.subplot(121) 
plt.plot(pacf_stock_plot)
plt.xticks(np.arange(21))
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(pacf_stock_plot)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(pacf_stock_plot)),linestyle='--',color='gray')
for i in range(1,20):
    plt.axvline(x=i,linestyle=':',color='gray')
plt.title('Partial Autocorrelation Function')
# Out:
# Text(0.5, 1.0, 'Partial Autocorrelation Function')

# %% [markdown]
# ### With differencing, the plot converts to:

# %%
acf_stock_plot = acf(diff, nlags=20, fft=True)
#Plot ACF: 
plt.figure(figsize=(20, 4))

plt.subplot(121) 
plt.plot(acf_stock_plot)
plt.xticks(np.arange(21))
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(acf_stock_plot)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(acf_stock_plot)),linestyle='--',color='gray')
for i in range(1,20):
    plt.axvline(x=i,linestyle=':',color='gray')
plt.title('Autocorrelation Function')
# Out:
# Text(0.5, 1.0, 'Autocorrelation Function')

# %%
pacf_stock_plot = pacf(diff, nlags=20)
#Plot PACF: 
plt.figure(figsize=(20, 4))

plt.subplot(121) 
plt.plot(pacf_stock_plot)
plt.xticks(np.arange(21))
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(pacf_stock_plot)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(pacf_stock_plot)),linestyle='--',color='gray')
for i in range(1,20):
    plt.axvline(x=i,linestyle=':',color='gray')
plt.title('Partial Autocorrelation Function')
# Out:
# Text(0.5, 1.0, 'Partial Autocorrelation Function')

# %%
model = ARIMA(diff, order=(1,0,0), freq=None)
model_fit = model.fit(disp=0)
print(model_fit.summary())
# plot residual errors
residuals = pd.DataFrame(model_fit.resid)
residuals.plot()
plt.show()
residuals.plot(kind='kde')
plt.show()
print(residuals.describe())
# Out:
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                 1090
# Model:                     ARMA(1, 0)   Log Likelihood               -1622.093
# Method:                       css-mle   S.D. of innovations              1.072
# Date:                Tue, 16 Jun 2020   AIC                           3250.186
# Time:                        19:55:43   BIC                           3265.168
# Sample:                             0   HQIC                          3255.856
#
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          -0.0436      0.034     -1.297      0.195      -0.110       0.022
# ar.L1.Close     0.0353      0.030      1.165      0.244      -0.024       0.095
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           28.3549           +0.0000j           28.3549            0.0000
# -----------------------------------------------------------------------------
#                  0
# count  1090.000000
# mean     -0.000036
# std       1.072164
# min     -18.541584
# 25%      -0.317274
# 50%       0.047215
# 75%       0.381009
# max       9.842591

# %%
model = ARIMA(price, order=(1,1,0), freq=None)
model_fit = model.fit(disp=0)
print(model_fit.summary())
# plot residual errors
residuals = pd.DataFrame(model_fit.resid)
residuals.plot()
plt.show()
residuals.plot(kind='kde')
plt.show()
print(residuals.describe())
# Out:
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                D.Close   No. Observations:                 1090
# Model:                 ARIMA(1, 1, 0)   Log Likelihood               -1622.093
# Method:                       css-mle   S.D. of innovations              1.072
# Date:                Tue, 16 Jun 2020   AIC                           3250.186
# Time:                        19:56:21   BIC                           3265.168
# Sample:                             1   HQIC                          3255.856
#
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -0.0436      0.034     -1.297      0.195      -0.110       0.022
# ar.L1.D.Close     0.0353      0.030      1.165      0.244      -0.024       0.095
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           28.3549           +0.0000j           28.3549            0.0000
# -----------------------------------------------------------------------------
#                  0
# count  1090.000000
# mean     -0.000036
# std       1.072164
# min     -18.541584
# 25%      -0.317274
# 50%       0.047215
# 75%       0.381009
# max       9.842591

# %%
loss_best = 1E16
best_ints = [-1,-1,-1]
for p in range(4):
    for d in range(3):
        for q in range(3):
            model = ARIMA(price, order=(p, d, q))  
            try:
                results_ARIMA = model.fit(disp=-1)
            except ValueError:
                pass
            except:
                pass
            plt.plot(price)
            plt.plot(results_ARIMA.fittedvalues, color='red')
            x=pd.DataFrame(results_ARIMA.fittedvalues)
            x=x.join(price)
            x['out']=(x.iloc[:,0]-x.iloc[:,1])**2
            loss=np.sqrt(x['out'].sum())
            plt.title('RSS: %.4f'% loss)
            if loss < loss_best:
                print(loss)
                loss_best = loss
                best_ints=[p,d,q]
            plt.show()
            print(p,d,q)
# Out:
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 390.32209175475845
# 0 0 0
# 210.16131406906825
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 0 0 1
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 0 0 2
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 0 1 0
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 0 1 1
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 0 1 2
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 0 2 0
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 0 2 1
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 0 2 2
# 45.65303604576876
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1 0 0
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1 0 1
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1 0 2
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1 1 0
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1 1 1
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1 1 2
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1 2 0
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1 2 1
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1 2 2
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 2 0 0
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 2 0 1
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 2 0 2
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 2 1 0
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 2 1 1
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 2 1 2
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 2 2 0
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 2 2 1
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:492: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 2 2 2
# 3 0 0
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 3 0 1
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 44.11886852687777
# 3 0 2
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 3 1 0
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 3 1 1
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 3 1 2
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 3 2 0
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 3 2 1
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:492: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
# 3 2 2

# %%
loss_best
# Out:
# 44.11886852687777

# %%
best_ints
# Out:
# [3, 0, 2]

# %%
loss_best = 1E16
best_ints = [-1,-1,-1]
for p in range(4):
    for d in range(3):
        for q in range(3):
            model = ARIMA(diff, order=(p, d, q))  
            try:
                results_ARIMA = model.fit(disp=-1)
            except ValueError:
                pass
            except:
                pass
            plt.plot(diff)
            plt.plot(results_ARIMA.fittedvalues, color='red')
            x=pd.DataFrame(results_ARIMA.fittedvalues)
            x=x.join(diff)
            x['out']=(x.iloc[:,0]-x.iloc[:,1])**2
            loss=np.sqrt(x['out'].sum())
            plt.title('RSS: %.4f'% loss)
            if loss < loss_best:
                print(loss)
                loss_best = loss
                best_ints=[p,d,q]
            plt.show()
            print(p,d,q)
# Out:
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 35.403429523833
# 0 0 0
# 35.382122663119915
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 0 0 1
# 35.37594327539932
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 0 0 2
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 0 1 0
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 0 1 1
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 0 1 2
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 0 2 0
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 0 2 1
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 0 2 2
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1 0 0
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1 0 1
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1 0 2
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1 1 0
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1 1 1
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1 1 2
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1 2 0
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1 2 1
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1 2 2
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 2 0 0
# 35.37015170445507
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 2 0 1
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 2 0 2
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 2 1 0
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 2 1 1
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:492: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
# 2 1 2
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 2 2 0
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 2 2 1
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 2 2 2
# 35.35171704620181
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 3 0 0
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 35.351716969268956
# 3 0 1
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 35.225648470864385
# 3 0 2
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 3 1 0
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 3 1 1
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:492: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 3 1 2
# 3 2 0
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 3 2 1
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 3 2 2

# %%
stock_price = price.astype(float)
loss_best = 1E16
best_ints = [-1,-1,-1]
for p in range(4):
    for d in range(3):
        for q in range(3):
            model = ARIMA(stock_price.dropna(), order=(p, d, q))  
            try:
                results_ARIMA = model.fit(disp=-1)
            except ValueError:
                pass
            except:
                pass
            plt.plot(stock_price)
            plt.plot(results_ARIMA.fittedvalues, color='red')
            x=pd.DataFrame(results_ARIMA.fittedvalues)
            x=x.join(stock_price)
            x['out']=(x.iloc[:,0]-x.iloc[:,1])**2
            loss=np.sqrt(x['out'].sum())
            plt.title('RSS: %.4f'% loss)
            if loss < loss_best:
                print(loss)
                loss_best = loss
                best_ints=[p,d,q]
            plt.show()
            print(p,d,q)
# Out:
# 359.157195090002
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 0 0 0
# 195.08119204397124
# 0 0 1
# 127.60885988994822
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 0 0 2
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 0 1 0
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 0 1 1
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 0 1 2
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 0 2 0
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 0 2 1
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 0 2 2
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 45.13442538713849
# 1 0 0
# 45.10898986544845
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1 0 1
# 45.10114341709969
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1 0 2
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1 1 0
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1 1 1
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1 1 2
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1 2 0
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1 2 1
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1 2 2
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 2 0 0
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:492: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 2 0 1
# 45.079133938651964
# 2 0 2
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 2 1 0
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 2 1 1
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 2 1 2
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 2 2 0
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 2 2 1
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 2 2 2
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 3 0 0
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 45.07814820292064
# 3 0 1
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 3 0 2
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 3 1 0
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 3 1 1
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 3 1 2
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 3 2 0
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 3 2 1
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/tsatools.py:668: RuntimeWarning: overflow encountered in exp
#   newparams = ((1-np.exp(-params))/(1+np.exp(-params))).copy()
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/tsatools.py:668: RuntimeWarning: invalid value encountered in true_divide
#   newparams = ((1-np.exp(-params))/(1+np.exp(-params))).copy()
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/tsatools.py:669: RuntimeWarning: overflow encountered in exp
#   tmp = ((1-np.exp(-params))/(1+np.exp(-params))).copy()
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/tsatools.py:669: RuntimeWarning: invalid value encountered in true_divide
#   tmp = ((1-np.exp(-params))/(1+np.exp(-params))).copy()
# /anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:492: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 3 2 2

# %%
loss_best
# Out:
# 35.225648470864385

# %%
best_ints
# Out:
# [3, 0, 2]

# %% [markdown]
# Make sure you can get the stock data (you should have at least this part up and running)
# **You can't use Fossil - use a different company**

# %%
stock_price = price.astype(float)

model = ARIMA(stock_price.dropna(), order=(3, 0, 2))  
results_ARIMA = model.fit(disp=-1)

plt.plot(stock_price)
plt.plot(results_ARIMA.fittedvalues, color='red')
x=pd.DataFrame(results_ARIMA.fittedvalues)
x=x.join(stock_price)
x['out']=(x.iloc[:,0]-x.iloc[:,1])**2
loss=np.sqrt(x['out'].sum())
plt.title('RSS: %.4f'% loss)

plt.show()
# Out:
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)

# %%
print(results_ARIMA.summary())
# plot residual errors
residuals = pd.DataFrame(results_ARIMA.resid)
residuals.plot()
plt.show()
residuals.plot(kind='kde')
plt.show()
print(residuals.describe())
# Out:
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                 1091
# Model:                     ARMA(3, 2)   Log Likelihood               -1619.795
# Method:                       css-mle   S.D. of innovations              1.062
# Date:                Tue, 16 Jun 2020   AIC                           3253.591
# Time:                        19:59:21   BIC                           3288.554
# Sample:                             0   HQIC                          3266.823
#
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          27.7621     16.854      1.647      0.100      -5.271      60.795
# ar.L1.Close     0.6110      0.011     54.778      0.000       0.589       0.633
# ar.L2.Close    -0.5966      0.017    -35.761      0.000      -0.629      -0.564
# ar.L3.Close     0.9824      0.009    114.873      0.000       0.966       0.999
# ma.L1.Close     0.4128      0.008     51.466      0.000       0.397       0.429
# ma.L2.Close     1.0000      0.016     64.465      0.000       0.970       1.030
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0013           -0.0000j            1.0013           -0.0000
# AR.2           -0.1970           -0.9888j            1.0082           -0.2813
# AR.3           -0.1970           +0.9888j            1.0082            0.2813
# MA.1           -0.2064           -0.9785j            1.0000           -0.2831
# MA.2           -0.2064           +0.9785j            1.0000            0.2831
# -----------------------------------------------------------------------------
#                  0
# count  1091.000000
# mean     -0.027867
# std       1.336031
# min     -18.482545
# 25%      -0.357148
# 50%      -0.020365
# 75%       0.353708
# max      26.547945
